# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from joblib import dump
import pandas as pd

# Example dataset (replace this with your actual dataset)
data = pd.read_csv('projects_dataset.csv')

# Extract features and labels
X = data['description'] + " " + data['synopsis']  # Combine text features
y = data['review_status']

# Vectorize the text features
vectorizer = CountVectorizer()
X_vectorized = vectorizer.fit_transform(X)

# Train Random Forest model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_vectorized, y)

# Save the model and vectorizer
dump(model, 'models/random_forest_model.joblib')
dump(vectorizer, 'models/vectorizer.joblib')

print("Model and vectorizer saved!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 22
#      19 model.fit(X_vectorized, y)
#      21 # Save the model and vectorizer
# ---> 22 dump(model, 'models/random_forest_model.joblib')
#      23 dump(vectorizer, 'models/vectorizer.joblib')
#      25 print("Model and vectorizer saved!")
#
# File d:\Projects\3rd year group project\prod\prodstudio-ml\prod_env\Lib\site-packages\joblib\numpy_pickle.py:552, in dump(value, filename, compress, protocol, cache_size)
#     550         NumpyPickler(f, protocol=protocol).dump(value)
#     551 elif is_filename:
# --> 552     with open(filename, 'wb') as f:
#     553         NumpyPickler(f, protocol=protocol).dump(value)
#     554 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/random_forest_model.joblib'

# %%
import os
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from joblib import dump
import pandas as pd

# Ensure the models directory exists
if not os.path.exists('models'):
    os.makedirs('models')

# Load dataset
try:
    data = pd.read_csv('projects_dataset.csv')
except FileNotFoundError:
    print("Error: 'projects_dataset.csv' not found. Please ensure the file exists.")
    exit()

# Check for required columns
required_columns = ['description', 'synopsis', 'review_status']
if not all(column in data.columns for column in required_columns):
    print(f"Error: Dataset is missing one or more required columns: {required_columns}")
    exit()

# Extract features and labels
X = data['description'] + " " + data['synopsis']  # Combine text features
y = data['review_status']

# Vectorize the text features
vectorizer = CountVectorizer()
X_vectorized = vectorizer.fit_transform(X)

# Train Random Forest model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_vectorized, y)

# Save the model and vectorizer
dump(model, 'models/random_forest_model.joblib')
dump(vectorizer, 'models/vectorizer.joblib')

print("Model and vectorizer saved successfully!")
# Out:
# Model and vectorizer saved successfully!
